# %%
from LWE_estimator.estimator import *

# %%
ND
# Out:
# <module 'LWE_estimator.estimator.nd' from '/home/ali/Research/CONAN_code/Conan_package_publish/CoNAN/Estimators/LWE_estimator/estimator/nd.py'>

# %%
int(509/3)
# Out:
# 169

# %%
# Xs  = estimator.ND.DiscreteGaussian(sqrt(2/3.))
# Xe  = estimator.ND.DiscreteGaussian(sqrt(2/3.))

Xs = ND.SparseTernary(169,169,509)
Xe = ND.SparseTernary(169,169,509)
l = NTRU.Parameters(
    n=509,
    q=2**11,
    Xs=Xs,
    Xe=Xe
)

# %%
NTRU.primal_usvp(l)['beta']
# Out:
# 383

# %%
Xs  = estimator.ND.DiscreteGaussian(1.22)
Xe  = estimator.ND.DiscreteGaussian(1.22)

l = estimator.NTRU.Parameters(
    n=int(128/2),
    q=2**11,
    Xs=Xs,
    Xe=Xe
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9807/4094685628.py in <module>
# ----> 1 Xs  = estimator.ND.DiscreteGaussian(1.22)
#       2 Xe  = estimator.ND.DiscreteGaussian(1.22)
#       3
#       4 l = estimator.NTRU.Parameters(
#       5     n=int(128/2),
#
# NameError: name 'estimator' is not defined

# %%
2*2/3
# Out:
# 1.3333333333333333

# %%
estimator.NTRU.primal_usvp(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9807/4062207627.py in <module>
# ----> 1 estimator.NTRU.primal_usvp(l)
#
# NameError: name 'estimator' is not defined

# %%
from sage.all import *

# %%
load("Fatigue_estimator/estimator.sage")
