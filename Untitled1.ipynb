# %%
from LWE_estimator.estimator import *

# %%
################## NTRU composite #######################
N = 512
q = 7681
d = int(N/3)

print(d)

print("check: ",(q-1)%N)
# Xs = ND.SparseTernary(d,d,N)
# Xe = ND.SparseTernary(d,d,N)

Xs = ND.DiscreteGaussian(math.sqrt(4/3.))
Xe = ND.DiscreteGaussian(math.sqrt(4/3.))
l = NTRU.Parameters(
    n=N,
    q=q,
    Xs=Xs,
    Xe=Xe
)

print(N,q,d)

print(NTRU.primal_usvp(l)['beta']*0.292)
# Out:
# 170
# check:  0
# 512 7681 170
# 103.076

# %%
##################### BQTRU #########################
N = 11
q = 191



n = 4*N**2

# Xs = ND.SparseTernary(4*d**2,4*d**2,n)
# Xe = ND.SparseTernary(4*d**2,4*d**2,n)

Xs = ND.DiscreteGaussian(math.sqrt(2/7.))
Xe = ND.DiscreteGaussian(math.sqrt(2/7.))

l = NTRU.Parameters(
    n=n,
    q=q,
    Xs=Xs,
    Xe=Xe
)


print(NTRU.primal_usvp(l)['beta']*0.292)
print((NTRU.primal_usvp(l))
# Out:
# 11 191 7
# 131.108

# %%
q = 2048

n = 587
Xs = ND.DiscreteGaussian(math.sqrt(2/3))
Xe = ND.DiscreteGaussian(math.sqrt(2/3))

l = NTRU.Parameters(
    n=n,
    q=q,
    Xs=Xs,
    Xe=Xe
)


print(NTRU.primal_usvp(l)['beta']*0.292)
# Out:
# 133.152

# %%
################## Indocrypt #####################
N = 139
q = 2237

n = 6*N
Xs = ND.DiscreteGaussian(math.sqrt(1.1))
Xe = ND.DiscreteGaussian(math.sqrt(1.1))

l = NTRU.Parameters(
    n=n,
    q=q,
    Xs=Xs,
    Xe=Xe
)


print(NTRU.primal_usvp(l)['beta']*0.292)
print(NTRU.primal_usvp(l)['beta'])
# Out:
# 214.61999999999998
# 735

# %%
################## Indocrypt folding #################
N = 139
q = 2237

n = 4*N
Xs = ND.DiscreteGaussian(math.sqrt(2.2))
Xe = ND.DiscreteGaussian(math.sqrt(2.2))

l = NTRU.Parameters(
    n=n,
    q=q,
    Xs=Xs,
    Xe=Xe
)


print(NTRU.primal_usvp(l)['beta']*0.292)
print(NTRU.primal_usvp(l)['beta'])
# Out:
# 147.75199999999998
# 506

# %%
#################### SQTRU ###################
N = 131
q = 2048

n = 4*N

Xs = ND.DiscreteGaussian(math.sqrt(2/3.))
Xe = ND.DiscreteGaussian(math.sqrt(2/3.))

l = NTRU.Parameters(
    n=n,
    q=q,
    Xs=Xs,
    Xe=Xe
)


print(NTRU.primal_usvp(l)['beta']*0.292)
print(NTRU.primal_usvp(l)['beta'])
# Out:
# 115.92399999999999
# 397

# %%
################### GRLWE ################

N = 256
q = 3329
n = 2*N

Xs = ND.DiscreteGaussian(math.sqrt(1.4884))
Xe = ND.DiscreteGaussian(math.sqrt(1.4884))

l = LWE.Parameters(
    n=n,
    q=q,
    Xs=Xs,
    Xe=Xe
)


print(LWE.primal_usvp(l)['beta']*0.292)
print(LWE.primal_usvp(l)['beta'])
# Out:
# 118.55199999999999
# 406

# %%
############ multivariate LWE ############

N1 = 
N2 =
q  =

# %%
Xs
# Out:
# T(p=49, m=49, n=196)
